# %%
import QuantLib as ql
import pandas as pd
from datetime import date
from utils import *

# %%
banking_params = connParams.copy()
banking_params['database'] = 'Bolsa'
banking_params['schema'] = 'basesbalance'

curves_params = connParams

banking_conn = connectDB(**banking_params)
curves_conn = connectDB(**curves_params)

# %% [markdown]
# ### Data from db

# %%
def term_translate(term):
    if 'O/N' in term or 'DY' in term:
        return str(ql.Period(1, ql.Days))
    elif 'MO' in term:
        tmp = term.replace('MO', '')
        return str(ql.Period(int(tmp), ql.Months))
    elif 'WK' in term:
        tmp = term.replace('WK', '')
        return str(ql.Period(int(tmp), ql.Weeks))
    elif 'YR' in term:
        tmp = term.replace('YR', '')
        return str(ql.Period(int(tmp), ql.Years))

def helper_type_translate(helper_type):
    return helper_type.upper()

# %%
sql = 'select * from rate_helper_params'
df = pd.read_sql(sql, banking_conn)
df = df[df.curve_name=='ICP']

tickers = df.bbg_ticker.to_list()
terms = df.term.to_list()
helper_types = df.rate_helper.to_list()

terms = list(map(term_translate, terms))
helper_types = list(map(helper_type_translate, helper_types))

# %%
add_tickers(tickers, curves_conn)
# Out:
# True

# %%
curves_params = {
    'curve_name': 'CF_USD',
    'day_counter': 'Act360',
    'enable_extrapolation': True,
    'config_date': date(2022, 7, 26),
}

helper_param = {
    'helper_name': 'EUR-EURIBOR-6M',
    'type':'DEPOSIT',
    'fields':['rate','tenor'],
    'values':[]
}
deposit_fields = ['rate', 'tenor', 'dayCounter']
bond_fields = ['rate', 'tenor', 'dayCounter', 'fixingDays', 'index',' discountingCurve']
swap_fields = ['rate', 'tenor', 'dayCounter']
ois_fields = ['tenor', 'rate', 'index', 'discountingCurve', 'frequency']

# %% [markdown]
# ### upload ICP

# %%
curves_params = {
    'curve_name': 'ICP_ICAP',
    'day_counter': 'Act360',
    'enable_extrapolation': True,
    'config_date': str(date(2022, 7, 26)),
}

curve_name = curves_params['curve_name']
helpers = []

process = [] 
for term, helper_type, ticker in zip(terms, helper_types, tickers):     
    if 'CMPN' not in ticker and term not in process:
        process.append(term)
        helper = {
            'helper_name': curve_name + '_' + term,
            'type': helper_type,
            'fields': None,
            'values': None
        }   
        if helper_type == 'DEPOSIT':
            helper['type'] = 'OIS'
            helper['fields'] = ois_fields
            helper['values'] = [term, ticker, 'ICPIndex', 'CLP_COLLUSD', 'ONCE']
        elif helper_type == 'OIS':
            helper['fields'] = ois_fields
            helper['values'] = [term, ticker, 'ICPIndex', 'CLP_COLLUSD', 'SEMIANNUAL']    
        elif helper_type == 'SWAP':
            helper['type'] = 'OIS'
            helper['fields'] = ois_fields
            helper['values'] = [term, ticker, 'ICPIndex', 'CLP_COLLUSD', 'SEMIANNUAL']  
        helpers.append(helper)      

upload_curve(curves_params, helpers, curves_conn)
# Out:
# {'curve_name': 'ICP_ICAP', 'day_counter': 'Act360', 'enable_extrapolation': True, 'config_date': '2022-07-26'}
# True

# %% [markdown]
# #### upload SOFR

# %%
sql = 'select * from rate_helper_params'
df = pd.read_sql(sql, banking_conn)
df = df[df.curve_name=='SOFR']

tickers = df.bbg_ticker.to_list()
terms = df.term.to_list()
helper_types = df.rate_helper.to_list()

terms = list(map(term_translate, terms))
helper_types = list(map(helper_type_translate, helper_types))

# %%
delete_curve(get_curve_id(curves_conn, 'SOFR'), curves_conn)
# Out:
# True

# %%
add_tickers(tickers, curves_conn)
# Out:
# True

# %%
deposit_fields = ['rate', 'tenor', 'dayCounter']
ois_fields = ['tenor', 'rate', 'index', 'frequency', 'calendar']

curves_params = {
    'curve_name': 'SOFR',
    'day_counter': 'Act360',
    'enable_extrapolation': True,
    'config_date': str(date(2022, 7, 25)),
}

curve_name = curves_params['curve_name']
helpers = []

process = [] 
for term, helper_type, ticker in zip(terms, helper_types, tickers):     
    if 'CMPN' not in ticker and term not in process:
        process.append(term)
        helper = {
            'helper_name': curve_name + '_' + term,
            'type': helper_type,
            'fields': None,
            'values': None
        }   
        if helper_type == 'DEPOSIT':
            helper['fields'] = deposit_fields
            helper['values'] = [ticker, term, 'Act360']
        elif helper_type == 'OIS':
            helper['fields'] = ois_fields
            helper['values'] = [term, ticker, 'SOFR', 'ANNUAL', 'USA']    
        helpers.append(helper)      

upload_curve(curves_params, helpers, curves_conn)
# Out:
# {'curve_name': 'SOFR', 'day_counter': 'Act360', 'enable_extrapolation': True, 'config_date': '2022-07-25'}
# True

# %% [markdown]
# ### upload LIBOR3M

# %%
sql = 'select * from rate_helper_params'
df = pd.read_sql(sql, banking_conn)
df = df[df.curve_name=='LIBOR3M']

tickers = df.bbg_ticker.to_list()
terms = df.term.to_list()
helper_types = df.rate_helper.to_list()

terms = list(map(term_translate, terms))
helper_types = list(map(helper_type_translate, helper_types))

# %%
deposit_fields = ['rate', 'tenor', 'dayCounter']
swap_fields = ['rate','tenor','index', 'frequency', 'discountingCurve', 'calendar']

curves_params = {
    'curve_name': 'LIBOR3M',
    'day_counter': 'Act360',
    'enable_extrapolation': True,
    'config_date': str(date(2022, 7, 25)),
}

curve_name = curves_params['curve_name']
helpers = []

process = [] 
ticks = []
for term, helper_type, ticker in zip(terms, helper_types, tickers):     
    if 'Comdty' not in ticker and term not in process:
        process.append(term)
        ticks.append(ticker)
        helper = {
            'helper_name': curve_name + '_' + term,
            'type': helper_type,
            'fields': None,
            'values': None
        }   
        if helper_type == 'DEPOSIT':
            helper['fields'] = deposit_fields
            helper['values'] = [ticker, term, 'Act360']
        elif helper_type == 'SWAP':
            helper['fields'] = swap_fields
            helper['values'] = [ticker, term, 'LIBOR3M', 'SEMIANNUAL', 'SOFR', 'USA']    
        helpers.append(helper)      

#

# %%
upload_curve(curves_params, helpers, curves_conn)
# Out:
# {'curve_name': 'LIBOR3M', 'day_counter': 'Act360', 'enable_extrapolation': True, 'config_date': '2022-07-25'}
# True

# %% [markdown]
# ### upload XCCY

# %%
sql = 'select * from rate_helper_params'
df = pd.read_sql(sql, banking_conn)
df = df[df.curve_name=='COLLATERAL_USDCLP']

tickers = df.bbg_ticker.to_list()
terms = df.term.to_list()
helper_types = df.rate_helper.to_list()

terms = list(map(term_translate, terms))
helper_types = list(map(helper_type_translate, helper_types))

# %%
fxswap_fields = ['FXPOINTS','SPOTFX', 'TENOR', 'CALENDAR', 'COLLATERALCURVE','ENDOFMONTH','BASECURRENCYCOLLATERAL']
xccy_fields = ['RATE','SPOTFX','TENOR','INDEX', 'FREQUENCY', 'DISCOUNTINGCURVE', 'CALENDAR']

curves_params = {
    'curve_name': 'CLP_COLLUSD',
    'day_counter': 'ACT360',
    'enable_extrapolation': True,
    'config_date': str(date(2022, 7, 25)),
}

curve_name = curves_params['curve_name']
helpers = []

process = [] 
ticks = []
for term, helper_type, ticker in zip(terms, helper_types, tickers):     
    if 'Comdty' not in ticker and term not in process:
        process.append(term)
        ticks.append(ticker)
        helper = {
            'helper_name': curve_name + '_' + term,
            'type': helper_type,
            'fields': None,
            'values': None
        }   
        if helper_type == 'FXSWAP':
            helper['fields'] = fxswap_fields
            helper['values'] = [ticker, term, 'Act360']
        elif helper_type == 'XCCY':
            helper['fields'] = xccy_fields
            helper['values'] = [ticker, term, 'LIBOR3M', 'SEMIANNUAL', 'SOFR', 'USA']    
        helpers.append(helper)
# Out:
#       idx         curve_name            bbg_ticker   day_counter   term  \
# 130   1.0  COLLATERAL_USDCLP          CHN1W Curncy  ACT_360_EOMC    1WK
# 131   2.0  COLLATERAL_USDCLP          CHN2W Curncy  ACT_360_EOMC   2 WK
# 132   3.0  COLLATERAL_USDCLP          CHN1M Curncy  ACT_360_EOMC   1 MO
# 133   4.0  COLLATERAL_USDCLP          CHN2M Curncy  ACT_360_EOMC   2 MO
# 134   5.0  COLLATERAL_USDCLP          CHN3M Curncy  ACT_360_EOMC   3 MO
# 135   6.0  COLLATERAL_USDCLP          CHN4M Curncy  ACT_360_EOMC   4 MO
# 136   7.0  COLLATERAL_USDCLP          CHN5M Curncy  ACT_360_EOMC   5 MO
# 137   8.0  COLLATERAL_USDCLP          CHN6M Curncy  ACT_360_EOMC   6 MO
# 138   9.0  COLLATERAL_USDCLP          CHN9M Curncy  ACT_360_EOMC   9 MO
# 139  10.0  COLLATERAL_USDCLP         CHN12M Curncy  ACT_360_EOMC  12 MO
# 140  11.0  COLLATERAL_USDCLP         CHN18M Curncy  ACT_360_EOMC  18 MO
# 141  12.0  COLLATERAL_USDCLP   CHUSBS2 ICCH Curncy  ACT_360_EOMC   2 YR
# 142  13.0  COLLATERAL_USDCLP   CHUSBS3 ICCH Curncy  ACT_360_EOMC   3 YR
# 143  14.0  COLLATERAL_USDCLP   CHUSBS4 ICCH Curncy  ACT_360_EOMC   4 YR
# 144  15.0  COLLATERAL_USDCLP   CHUSBS5 ICCH Curncy  ACT_360_EOMC   5 YR
# 145  16.0  COLLATERAL_USDCLP   CHUSBS6 ICCH Curncy  ACT_360_EOMC   6 YR
# 146  17.0  COLLATERAL_USDCLP   CHUSBS7 ICCH Curncy  ACT_360_EOMC   7 YR
# 147  18.0  COLLATERAL_USDCLP   CHUSBS8 ICCH Curncy  ACT_360_EOMC   8 YR
# 148  19.0  COLLATERAL_USDCLP   CHUSBS9 ICCH Curncy  ACT_360_EOMC   9 YR
# 149  20.0  COLLATERAL_USDCLP  CHUSBS10 ICCH Curncy  ACT_360_EOMC  10 YR
# 150  21.0  COLLATERAL_USDCLP  CHUSBS15 ICCH Curncy  ACT_360_EOMC  15 YR
# 152  22.0  COLLATERAL_USDCLP  CHUSBS20 ICCH Curncy  ACT_360_EOMC  20 YR
# 153  23.0  COLLATERAL_USDCLP  CHUSBS25 ICCH Curncy  ACT_360_EOMC  25 YR
# 154  24.0  COLLATERAL_USDCLP  CHUSBS30 ICCH Curncy  ACT_360_EOMC  30 YR
#
#     instrument_type   frequency rate_helper      buss_adj   eom  payment_lag  \
# 130          FXSWAP        ZERO      FxSwap  ModFollowing  True          0.0
# 131          FXSWAP        ZERO      FxSwap  ModFollowing  True          0.0
# 132          FXSWAP        ZERO      FxSwap  ModFollowing  True          0.0
# 133          FXSWAP        ZERO      FxSwap  ModFollowing  True          0.0
# 134          FXSWAP        ZERO      FxSwap  ModFollowing  True          0.0
# 135          FXSWAP        ZERO      FxSwap  ModFollowing  True          0.0
# 136          FXSWAP        ZERO      FxSwap  ModFollowing  True          0.0
# 137          FXSWAP        ZERO      FxSwap  ModFollowing  True          0.0
# 138          FXSWAP        ZERO      FxSwap  ModFollowing  True          0.0
# 139          FXSWAP        ZERO      FxSwap  ModFollowing  True          0.0
# 140          FXSWAP        ZERO      FxSwap  ModFollowing  True          0.0
# 141         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
# 142         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
# 143         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
# 144         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
# 145         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
# 146         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
# 147         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
# 148         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
# 149         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
# 150         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
# 152         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
# 153         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
# 154         SPREADS  SEMIANNUAL    CrossFix  ModFollowing  True          0.0
#
#      settlement_days      calendar      fix_base_ticker base_as_collateral
# 130              0.0  UnitedStates                 None               True
# 131              0.0  UnitedStates                 None               True
# 132              0.0  UnitedStates                 None               True
# 133              0.0  UnitedStates                 None               True
# 134              0.0  UnitedStates                 None               True
# 135              0.0  UnitedStates                 None               True
# 136              0.0  UnitedStates                 None               True
# 137              0.0  UnitedStates                 None               True
# 138              0.0  UnitedStates                 None               True
# 139              0.0  UnitedStates                 None               True
# 140              0.0  UnitedStates                 None               True
# 141              2.0  UnitedStates   CHSWP2 ICCH Curncy               None
# 142              2.0  UnitedStates   CHSWP3 ICCH Curncy               None
# 143              2.0  UnitedStates   CHSWP4 ICCH Curncy               None
# 144              2.0  UnitedStates   CHSWP5 ICCH Curncy               None
# 145              2.0  UnitedStates   CHSWP6 ICCH Curncy               None
# 146              2.0  UnitedStates   CHSWP7 ICCH Curncy               None
# 147              2.0  UnitedStates   CHSWP8 ICCH Curncy               None
# 148              2.0  UnitedStates   CHSWP9 ICCH Curncy               None
# 149              2.0  UnitedStates  CHSWP10 ICCH Curncy               None
# 150              2.0  UnitedStates  CHSWP15 ICCH Curncy               None
# 152              2.0  UnitedStates  CHSWP20 ICCH Curncy               None
# 153              2.0  UnitedStates  CHSWP25 ICCH Curncy               None
# 154              2.0  UnitedStates  CHSWP30 ICCH Curncy               None
